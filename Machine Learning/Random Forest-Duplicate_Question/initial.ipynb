# %% [markdown]
# First we will import all the Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing CSV data file

# %%
df = pd.read_csv("train.csv")
#shape to check rows and columns
df.shape
# Out:
# (404290, 6)

# %%
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
df.sample(20)
# Out:
#             id    qid1    qid2  \
# 153912  153912   73384  241485
# 218920  218920  325665  325666
# 206573  206573  310032  310033
# 312491  312491  436937  436938
# 292347  292347  100091  413931
# 61717    61717  107695  107696
# 308651  308651  432518  124982
# 187661  187661  224137  120649
# 28168    28168   52254   52255
# 393421  393421  145680  526214
# 32681    32681   60130   60131
# 87980    87980  148071   42683
# 171905  171905  252958  265560
# 279084  279084  143018  249107
# 235723  235723  346488   28953
# 115974  115974  189016  189017
# 399494  399494   21418  297196
# 264436  264436  381197  381198
# 398041  398041  531235  531236
# 165529  165529  257021  257022
#
#                                                 question1  \
# 153912                         Is Taylor Swift overrated?
# 218920  What is the life of sugarcane after it is harv...
# 206573  Can we use two pulseIn() functions simultaneou...
# ...

# %%
# to check the data type present in the project
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
# missing values
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
#duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Distribution of duplicate and non-duplicate question present in dataset

# %%
print(df['is_duplicate'].value_counts())
print((df['is_duplicate'].value_counts()/df['is_duplicate'].count())*100)
df['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# 0    255027
# 1    149263
# Name: is_duplicate, dtype: int64
# 0    63.080215
# 1    36.919785
# Name: is_duplicate, dtype: float64
# <AxesSubplot: >

# %%
# Repeated questions

qid = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
print('Number of unique questions',np.unique(qid).shape[0])
x = qid.value_counts()>1
print('Number of repeated questions',x[x].shape[0])
# Out:
# Number of unique questions 537933
# Number of repeated questions 111780

# %%
# Repeated questions histogram

plt.hist(qid.value_counts().values,bins=160)
plt.yscale('log')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('USA_Housing.csv')

# %%
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
data.shape
# Out:
# (5000, 7)

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
#corr() shows correlation between columns 
sns.heatmap(data.corr())
# Out:
# C:\Users\saisi\AppData\Local\Temp\ipykernel_27192\3550697670.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %%
sns.pairplot(data)

# %%
sns.displot(data['Area Population'])

# %%
sns.distplot(data['Price'],bins=50,kde=True)
# Out:
# C:\Users\saisi\AppData\Local\Temp\ipykernel_27192\920938619.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'],bins=50,kde=True)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X=data[['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']]

# %%
y=data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
print(X_test,y_test)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2121      73278.804405             6.270914                   7.370286
# 2800      89475.559699             6.888439                   5.233514
# 1792      85526.620937             5.720213                   6.335377
# 538       79698.220917             4.102336                   6.912506
# 3915      88733.448030             4.740032                   7.914387
# ...                ...                  ...                        ...
# 2425      74551.972984             6.893317                   7.504692
# 1571      77785.192610             4.254128                   5.865544
# 1218      71172.489061             5.780419                   6.102668
# 4446      66357.880170             6.497222                   7.028679
# 4114      67830.628752             6.498985                   8.117274
#
#       Avg. Area Number of Bedrooms  Area Population
# 2121                          4.03     23586.382745
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# -2638673.426190405

# %%
reg.coef_
# Out:
# array([2.16257989e+01, 1.65590393e+05, 1.19827783e+05, 2.36109526e+03,
#        1.52165814e+01])

# %%
def calc(slope, intercept, hours):
    return slope * hours + intercept

# %%
data = calc(reg.coef_, reg.intercept_,9.5)

# %%
print(data)
# Out:
# [-2638467.98110046 -1065564.69510024 -1500309.48398691 -2616243.02119787
#  -2638528.86866715]

# %%
y_pred = reg.predict(X_test)

# %%
print(y_pred)
# Out:
# [1308536.13592598 1237122.72746455 1243835.62817085 ... 1457119.79297219
#  1483428.9530929  1047510.5973721 ]

# %%
hpp = pd.DataFrame({'Actual': y_test.squeeze(),'Predicted': y_pred.squeeze()})

# %%
hpp.plot.scatter(x = 'Actual', y = 'Predicted', title = 'PLOT BETWEEN AND PREDICTED')
# Out:
# <Axes: title={'center': 'PLOT BETWEEN AND PREDICTED'}, xlabel='Actual', ylabel='Predicted'>

# %%
print(hpp)
# Out:
#             Actual     Predicted
# 1501  1.339096e+06  1.308536e+06
# 2586  1.251794e+06  1.237123e+06
# 2653  1.340095e+06  1.243836e+06
# 1055  1.431508e+06  1.229242e+06
# 705   1.042374e+06  1.059353e+06
# ...            ...           ...
# 3563  1.348222e+06  1.437325e+06
# 1538  1.309937e+06  1.094962e+06
# 1837  1.472887e+06  1.457120e+06
# 2380  1.409762e+06  1.483429e+06
# 1912  1.009606e+06  1.047511e+06
#
# [1500 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print(f'Mean absolute error : {mae:.2f}')
print(f'Mean squared error : {mse:.2f}')
print(f'root Mean absolute error : {rmse:.2f}')
# Out:
# Mean absolute error : 81135.57
# Mean squared error : 10068422551.40
# root Mean absolute error : 100341.53
